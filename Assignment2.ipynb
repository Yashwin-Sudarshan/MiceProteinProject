# %%
# Task 1: Data Preparation
# Loading data from csv file, naming columns, and skipping first 2 rows as they are labels
import pandas as pd
mouse_p = "Data_Cortex_Nuclear.csv"
mouse_data = pd.read_csv(mouse_p, sep=',', decimal='.', header = 0, skiprows = 1)

# %%
# Viewing first 5 rows of dataset
mouse_data.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1   309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2   309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3   309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4   309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...   pCFOS_N     SYP_N  H3AcK18_N  \
# 0  0.177565   2.373744  0.232224  ...  0.108336  0.427099   0.114783
# 1  0.172817   2.292150  0.226972  ...  0.104315  0.441581   0.111974
# 2  0.175722   2.283337  0.230247  ...  0.106219  0.435777   0.111883
# 3  0.176463   2.152301  0.207004  ...  0.111262  0.391691   0.130405
# 4  0.173627   2.134014  0.192158  ...  0.110694  0.434154   0.118481
#
#      EGR1_N  H3MeK4_N    CaNA_N  Genotype  Treatment  Behavior   class
# ...

# %%
# Checking the if loaded dataset shape is equivalent to csv file (1082, 82); output should
# have 1080 rows since one row was skipped and the next row contains the column labels
mouse_data.shape
# Out:
# (1080, 82)

# %%
# Checking if the loaded dataset has the appropriate data types assigned to each column
pd.set_option("display.max_rows", 82)
mouse_data.dtypes
# Out:
# MouseID             object
# DYRK1A_N           float64
# ITSN1_N            float64
# BDNF_N             float64
# NR1_N              float64
# NR2A_N             float64
# pAKT_N             float64
# pBRAF_N            float64
# pCAMKII_N          float64
# pCREB_N            float64
# pELK_N             float64
# pERK_N             float64
# pJNK_N             float64
# PKCA_N             float64
# pMEK_N             float64
# pNR1_N             float64
# pNR2A_N            float64
# pNR2B_N            float64
# pPKCAB_N           float64
# pRSK_N             float64
# AKT_N              float64
# BRAF_N             float64
# CAMKII_N           float64
# CREB_N             float64
# ELK_N              float64
# ERK_N              float64
# GSK3B_N            float64
# JNK_N              float64
# MEK_N              float64
# TRKA_N             float64
# RSK_N              float64
# APP_N              float64
# Bcatenin_N         float64
# SOD1_N             float64
# ...

# %%
# Check for missing values 
# Missing values will not be replaced yet as some feature columns have a large number of 
# missing values
mouse_data[mouse_data.notnull()].count()
# Out:
# MouseID            1080
# DYRK1A_N           1077
# ITSN1_N            1077
# BDNF_N             1077
# NR1_N              1077
# NR2A_N             1077
# pAKT_N             1077
# pBRAF_N            1077
# pCAMKII_N          1077
# pCREB_N            1077
# pELK_N             1077
# pERK_N             1077
# pJNK_N             1077
# PKCA_N             1077
# pMEK_N             1077
# pNR1_N             1077
# pNR2A_N            1077
# pNR2B_N            1077
# pPKCAB_N           1077
# pRSK_N             1077
# AKT_N              1077
# BRAF_N             1077
# CAMKII_N           1077
# CREB_N             1077
# ELK_N              1062
# ERK_N              1077
# GSK3B_N            1077
# JNK_N              1077
# MEK_N              1073
# TRKA_N             1077
# RSK_N              1077
# APP_N              1077
# Bcatenin_N         1062
# SOD1_N             1077
# MTOR_N             1077
# P38_N              1077
# pMTOR_N            1077
# DSCR1_N            1077
# ...

# %%
# Holistically checking for impossible values for numerical features
pd.set_option("display.max_columns", 82)
mouse_data.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249362     0.251640     0.049383     0.347293     0.933100
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288121     0.473361     0.287444     2.057411     3.155678
# 50%       0.366378     0.565782     0.316564     2.296546     3.760855
# 75%       0.487711     0.698032     0.348197     2.528481     4.440011
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.233168     0.181846     3.537109     0.212574     1.428682
# std       0.041634     0.027042     1.295169     0.032587     0.466904
# ...

# %%
# The "RRP1_N" feature column had a negative min value 
# We will formally check if any other numerical columns have negative values
mouse_data_numerical = mouse_data.drop(columns=['MouseID', 'Genotype', 'Treatment', 'Behavior', 'class'])
mouse_data_numerical[mouse_data_numerical < 0].count()
# Out:
# DYRK1A_N           0
# ITSN1_N            0
# BDNF_N             0
# NR1_N              0
# NR2A_N             0
# pAKT_N             0
# pBRAF_N            0
# pCAMKII_N          0
# pCREB_N            0
# pELK_N             0
# pERK_N             0
# pJNK_N             0
# PKCA_N             0
# pMEK_N             0
# pNR1_N             0
# pNR2A_N            0
# pNR2B_N            0
# pPKCAB_N           0
# pRSK_N             0
# AKT_N              0
# BRAF_N             0
# CAMKII_N           0
# CREB_N             0
# ELK_N              0
# ERK_N              0
# GSK3B_N            0
# JNK_N              0
# MEK_N              0
# TRKA_N             0
# RSK_N              0
# APP_N              0
# Bcatenin_N         0
# SOD1_N             0
# MTOR_N             0
# P38_N              0
# pMTOR_N            0
# DSCR1_N            0
# AMPKA_N            0
# NR2B_N             0
# pNUMB_N            0
# RAPTOR_N           0
# TIAM1_N            0
# pP70S6_N           0
# ...

# %%
# Removing row containing negative impossible value in "RRP1_N" feature column
mouse_data = mouse_data[mouse_data["RRP1_N"] >= 0]

# %%
# Checking categorical features for typos and extra whitespace
mouse_data["Genotype"].value_counts()
# Out:
# Control    569
# Ts65Dn     510
# Name: Genotype, dtype: int64

# %%
# Checking categorical features for typos and extra whitespace
mouse_data["Treatment"].value_counts()
# Out:
# Memantine    569
# Saline       510
# Name: Treatment, dtype: int64

# %%
# Checking categorical features for typos and extra whitespace
mouse_data["Behavior"].value_counts()
# Out:
# S/C    554
# C/S    525
# Name: Behavior, dtype: int64

# %%
# Checking categorical features for typos and extra whitespace
mouse_data["class"].value_counts()
# Out:
# c-CS-m    150
# c-SC-m    149
# t-CS-m    135
# c-SC-s    135
# t-SC-s    135
# c-CS-s    135
# t-SC-m    135
# t-CS-s    105
# Name: class, dtype: int64

# %%
# Task 2: Data Exploration
# Creating a pie chart to display distributions of classes of mice in the dataset
import matplotlib.pyplot as plt
# %matplotlib inline
mouse_data["class"].value_counts().plot(kind="pie", autopct="%.1f")
plt.title("Figure 1: Pie Chart of Mice Classes")
plt.ylabel("")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the AcetylH3K9_N protein
mouse_data["AcetylH3K9_N"].dropna().plot(kind="box")
plt.title("Figure 2: Box plot of the AcetylH3K9_N protein")
plt.ylabel('Protein expression level')
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the RRP1_N protein
mouse_data["RRP1_N"].dropna().plot(kind="box")
plt.title("Figure 3: Box plot of the RRP1_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the EGR1_N protein
mouse_data["EGR1_N"].dropna().plot(kind="box")
plt.title("Figure 4: Box plot of the EGR1_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the BCL2_N protein
mouse_data["BCL2_N"].dropna().plot(kind="box")
plt.title("Figure 5: Box plot of the BCL2_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the NR1_N protein
mouse_data["NR1_N"].dropna().plot(kind="box")
plt.title("Figure 6: Box plot of the NR1_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the ELK_N protein
mouse_data["ELK_N"].dropna().plot(kind="box")
plt.title("Figure 7: Box plot of the ELK_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the Ubiquitin_N protein
mouse_data["Ubiquitin_N"].dropna().plot(kind="box")
plt.title("Figure 8: Box plot of the Ubiquitin_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the pGSK3B_Tyr216_N protein
mouse_data["pGSK3B_Tyr216_N"].dropna().plot(kind="box")
plt.title("Figure 9: Box plot of the pGSK3B_Tyr216_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the RAPTOR_N protein
mouse_data["RAPTOR_N"].dropna().plot(kind="box")
plt.title("Figure 10: Box plot of the RAPTOR_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the numerical distribution of the Bcatenin_N protein
mouse_data["Bcatenin_N"].dropna().plot(kind="box")
plt.title("Figure 11: Box plot of the Bcatenin_N protein")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Removing extreme outliers from explored protein feature columns
for i in range(2):
    mouse_data = mouse_data[mouse_data["AcetylH3K9_N"] != mouse_data["AcetylH3K9_N"].max()]
    mouse_data = mouse_data[mouse_data["RRP1_N"] != mouse_data["RRP1_N"].max()]
    mouse_data = mouse_data[mouse_data["EGR1_N"] != mouse_data["EGR1_N"].max()]
    mouse_data = mouse_data[mouse_data["BCL2_N"] != mouse_data["BCL2_N"].max()]
    mouse_data = mouse_data[mouse_data["NR1_N"] != mouse_data["NR1_N"].max()]
    mouse_data = mouse_data[mouse_data["ELK_N"] != mouse_data["ELK_N"].max()]
    mouse_data = mouse_data[mouse_data["Ubiquitin_N"] != mouse_data["Ubiquitin_N"].max()]
    mouse_data = mouse_data[mouse_data["pGSK3B_Tyr216_N"] != mouse_data["pGSK3B_Tyr216_N"].max()]
    mouse_data = mouse_data[mouse_data["RAPTOR_N"] != mouse_data["RAPTOR_N"].max()]
    mouse_data = mouse_data[mouse_data["Bcatenin_N"] != mouse_data["Bcatenin_N"].max()]

mouse_data[mouse_data.notnull()].count()
# Out:
# MouseID            1059
# DYRK1A_N           1056
# ITSN1_N            1056
# BDNF_N             1056
# NR1_N              1056
# NR2A_N             1056
# pAKT_N             1056
# pBRAF_N            1056
# pCAMKII_N          1056
# pCREB_N            1056
# pELK_N             1056
# pERK_N             1056
# pJNK_N             1056
# PKCA_N             1056
# pMEK_N             1056
# pNR1_N             1056
# pNR2A_N            1056
# pNR2B_N            1056
# pPKCAB_N           1056
# pRSK_N             1056
# AKT_N              1056
# BRAF_N             1056
# CAMKII_N           1056
# CREB_N             1056
# ELK_N              1041
# ERK_N              1056
# GSK3B_N            1056
# JNK_N              1056
# MEK_N              1052
# TRKA_N             1056
# RSK_N              1056
# APP_N              1056
# Bcatenin_N         1041
# SOD1_N             1056
# MTOR_N             1056
# P38_N              1056
# pMTOR_N            1056
# DSCR1_N            1056
# ...

# %%
# Creating a box plot to display the distribution of the NR1_N protein according to the 
# genotype of the mice
mouse_data.dropna().boxplot(column="NR1_N", by="Genotype")
plt.title("Figure 12: Box plot of NR1_N protein grouped by Genotype")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a scatter plot to visualise the relationship between the levels of EGR1_N and
# BCL2_N protein levels in the mice
mouse_data.plot(kind="scatter", x="EGR1_N", y="BCL2_N")
plt.title("Figure 13: Scatter plot of the relationship between the EGR1_N and BCL2_N " 
         + "protein levels in the mice")
plt.show()

# %%
# Creating a scatter plot to visualise the relationship between the levels of AcetylH3K9_N 
# and RRP1_N protein levels in the mice
mouse_data.plot(kind="scatter", x="AcetylH3K9_N", y="RRP1_N")
plt.title("Figure 14: Scatter plot of the relationship between the AcetylH3K9_N and RRP1_N " 
         + "protein levels in the mice")
plt.show()

# %%
# Creating a box plot to display the distribution of the RAPTOR_N protein according to the 
# classes of the mice
mouse_data.dropna().boxplot(column="RAPTOR_N", by="class")
plt.title("Figure 15: Box plot of RAPTOR_N protein grouped by class")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the distribution of the Ubiquitin_N protein according to the 
# treatments of the mice
mouse_data.dropna().boxplot(column="Ubiquitin_N", by="Treatment")
plt.title("Figure 16: Box plot of Ubiquitin_N protein grouped by Treatment")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the distribution of the pGSK3B_Tyr216_N protein according 
# to the behavior of the mice
mouse_data.dropna().boxplot(column="pGSK3B_Tyr216_N", by="Behavior")
plt.title("Figure 17: Box plot of pGSK3B_Tyr216_N protein grouped by Behavior")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a scatter plot to visualise the relationship between the levels of ELK_N and
# Bcatenin_N protein levels in the mice
mouse_data.plot(kind="scatter", x="ELK_N", y="Bcatenin_N")
plt.title("Figure 18: Scatter plot of the relationship between the ELK_N and Bcatenin_N " 
         + "protein levels in the mice")
plt.show()

# %%
# Creating a box plot to display the distribution of the pGSK3B_Tyr216_N protein according 
# to the classes of the mice
mouse_data.dropna().boxplot(column="pGSK3B_Tyr216_N", by="class")
plt.title("Figure 19: Box plot of pGSK3B_Tyr216_N protein grouped by class")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the distribution of the AcetylH3K9_N protein according 
# to the genotype of the mice
mouse_data.dropna().boxplot(column="AcetylH3K9_N", by="Genotype")
plt.title("Figure 20: Box plot of AcetylH3K9_N protein grouped by Genotype")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Creating a box plot to display the distribution of the RRP1_N protein according 
# to the genotype of the mice
mouse_data.dropna().boxplot(column="RRP1_N", by="Genotype")
plt.title("Figure 21: Box plot of RRP1_N protein grouped by Genotype")
plt.suptitle("")
plt.ylabel("Protein expression level")
plt.show()

# %%
# Task 3: Modelling
# Remove 'MouseID' column from dataset as it does not contain helpful predictive potential
mouse_data = mouse_data.drop(columns="MouseID")

# %%
# Dropping target class column and categorical determiners
mouse_data_wo_cat = mouse_data.drop(columns=['class','Genotype','Treatment','Behavior'])
mouse_data_wo_cat.head()
# Out:
#    DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830  0.177565
# 1  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636  0.172817
# 2  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011  0.175722
# 3  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886  0.176463
# 4  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106  0.173627
#
#    pCAMKII_N   pCREB_N    pELK_N    pERK_N    pJNK_N    PKCA_N    pMEK_N  \
# 0   2.373744  0.232224  1.750936  0.687906  0.306382  0.402698  0.296927
# 1   2.292150  0.226972  1.596377  0.695006  0.299051  0.385987  0.281319
# 2   2.283337  0.230247  1.561316  0.677348  0.291276  0.381002  0.281710
# 3   2.152301  0.207004  1.595086  0.583277  0.296729  0.377087  0.313832
# 4   2.134014  0.192158  1.504230  0.550960  0.286961  0.363502  0.277964
#
#      pNR1_N   pNR2A_N   pNR2B_N  pPKCAB_N    pRSK_N     AKT_N    BRAF_N  \
# ...

# %%
# Fill missing values in dataset with a negative constant
mouse_data_wo_cat = mouse_data_wo_cat.fillna(-1)

# %%
# Split the dataset into training and testing datasets
from sklearn.model_selection import train_test_split
X = mouse_data_wo_cat
y = mouse_data["class"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Checking shapes of training and testing split data
X_train
# Out:
#       DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 515   0.260145  0.465398  0.309689  2.619377  4.128657  0.231519  0.184649
# 948   0.286238  0.519021  0.300679  1.817545  2.763013  0.207565  0.152818
# 664   0.612545  0.848253  0.342264  2.359798  3.996296  0.215212  0.179775
# 640   0.620657  0.850280  0.248359  1.944436  2.798399  0.169095  0.144596
# 453   0.330938  0.561575  0.369450  2.966949  5.445610  0.258227  0.203334
# ...        ...       ...       ...       ...       ...       ...       ...
# 1054  0.268433  0.447237  0.300984  2.157154  3.037699  0.235428  0.178350
# 781   0.382976  0.588608  0.307672  2.771248  5.116507  0.245673  0.177344
# 853   0.391991  0.555107  0.286921  1.939383  2.814475  0.324761  0.212344
# 572   0.956488  1.108441  0.384049  2.662564  4.606357  0.203799  0.171625
# 698   0.643166  0.907501  0.315903  2.317526  3.415074  0.239272  0.184818
#
# ...

# %%
X_train.shape
# Out:
# (847, 77)

# %%
y_train
# Out:
# 515     c-SC-s
# 948     t-SC-s
# 664     t-CS-m
# 640     t-CS-m
# 453     c-SC-s
#          ...
# 1054    t-SC-s
# 781     t-SC-m
# 853     t-CS-s
# 572     t-CS-m
# 698     t-CS-m
# Name: class, Length: 847, dtype: object

# %%
y_train.shape
# Out:
# (847,)

# %%
X_test
# Out:
#      DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 427  0.409277  0.545703  0.309686  2.232469  3.765894  0.275580  0.185266
# 205  0.267745  0.409186  0.280010  1.867171  2.740084  0.283664  0.220772
# 696  0.715018  0.925954  0.338903  2.373457  3.556863  0.250807  0.194798
# 320  0.377388  0.630611  0.390998  2.666428  5.101839  0.244389  0.176695
# 270  0.286789  0.497917  0.337858  2.589437  4.283833  0.271469  0.191641
# ..        ...       ...       ...       ...       ...       ...       ...
# 832  0.396521  0.625472  0.268012  2.026588  3.763827  0.218776  0.160512
# 870  0.523508  0.860404  0.355558  2.433010  4.030709  0.185886  0.156083
# 286  0.309432  0.539782  0.347400  2.544861  4.586578  0.237969  0.184401
# 504  0.246061  0.396566  0.269697  2.138182  2.826263  0.186869  0.155758
# 252  0.290638  0.333142  0.268237  1.838599  2.613441  0.193280  0.180069
#
#      pCAMKII_N   pCREB_N    pELK_N    pERK_N    pJNK_N    PKCA_N    pMEK_N  \
# ...

# %%
X_test.shape
# Out:
# (212, 77)

# %%
y_test
# Out:
# 427    c-CS-s
# 205    c-SC-m
# 696    t-CS-m
# 320    c-CS-s
# 270    c-SC-m
#         ...
# 832    t-SC-m
# 870    t-CS-s
# 286    c-SC-m
# 504    c-SC-s
# 252    c-SC-m
# Name: class, Length: 212, dtype: object

# %%
y_test.shape
# Out:
# (212,)

# %%
# Selecting a k-NearestNeighbour classifier and fitting data
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(5)
fit = clf.fit(X_train, y_train)
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array(['c-CS-s', 'c-SC-m', 't-CS-m', 'c-CS-s', 'c-SC-m', 't-SC-m',
#        't-SC-s', 'c-SC-m', 't-CS-m', 't-SC-s', 't-SC-m', 't-CS-m',
#        'c-CS-m', 'c-CS-s', 't-SC-m', 'c-CS-m', 't-CS-s', 'c-SC-s',
#        't-CS-s', 't-CS-m', 'c-CS-s', 't-SC-s', 'c-SC-m', 'c-SC-s',
#        't-CS-m', 'c-CS-m', 'c-SC-s', 'c-CS-s', 'c-CS-s', 'c-CS-m',
#        'c-SC-s', 't-CS-m', 'c-SC-s', 'c-CS-m', 'c-SC-m', 'c-CS-s',
#        't-CS-m', 'c-CS-m', 'c-SC-s', 't-CS-m', 'c-SC-m', 't-CS-m',
#        't-SC-s', 't-SC-m', 't-SC-m', 'c-SC-s', 't-SC-s', 't-SC-m',
#        't-SC-m', 'c-CS-m', 'c-CS-m', 'c-CS-s', 't-CS-m', 'c-SC-s',
#        't-SC-s', 'c-SC-m', 't-SC-m', 't-SC-m', 'c-SC-s', 'c-CS-s',
#        't-CS-m', 't-CS-s', 'c-CS-m', 't-CS-m', 't-CS-s', 'c-SC-m',
#        't-CS-m', 't-SC-s', 'c-CS-s', 't-CS-s', 'c-CS-s', 'c-SC-s',
#        'c-CS-s', 'c-SC-s', 't-CS-m', 'c-CS-m', 'c-SC-s', 'c-SC-s',
#        'c-SC-m', 'c-SC-s', 'c-SC-m', 'c-SC-s', 'c-CS-m', 'c-SC-m',
# ...

# %%
y_pre.shape
# Out:
# (212,)

# %%
# Evaluating performance
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pre)
print(cm)
# Out:
# [[24  1  0  0  1  0  0  0]
#  [ 1 19  0  0  1  0  0  0]
#  [ 0  0 23  0  0  0  0  0]
#  [ 0  0  0 33  0  0  0  0]
#  [ 0  0  0  0 30  0  0  2]
#  [ 0  2  0  0  2 20  0  0]
#  [ 0  0  0  0  0  0 28  0]
#  [ 0  0  0  0  0  0  0 25]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pre))
# Out:
#               precision    recall  f1-score   support
#
#       c-CS-m       0.96      0.92      0.94        26
#       c-CS-s       0.86      0.90      0.88        21
#       c-SC-m       1.00      1.00      1.00        23
#       c-SC-s       1.00      1.00      1.00        33
#       t-CS-m       0.88      0.94      0.91        32
#       t-CS-s       1.00      0.83      0.91        24
#       t-SC-m       1.00      1.00      1.00        28
#       t-SC-s       0.93      1.00      0.96        25
#
#     accuracy                           0.95       212
#    macro avg       0.95      0.95      0.95       212
# weighted avg       0.96      0.95      0.95       212

# %%
# Experimenting with k-NearestNeighbours parameters
clf = KNeighborsClassifier(3, weights='distance', p=1)
fit = clf.fit(X_train, y_train)
y_pre = fit.predict(X_test)
cm = confusion_matrix(y_test, y_pre)
print(classification_report(y_test, y_pre))
# Out:
#               precision    recall  f1-score   support
#
#       c-CS-m       1.00      1.00      1.00        26
#       c-CS-s       1.00      0.90      0.95        21
#       c-SC-m       0.96      1.00      0.98        23
#       c-SC-s       1.00      0.97      0.98        33
#       t-CS-m       0.94      0.97      0.95        32
#       t-CS-s       1.00      1.00      1.00        24
#       t-SC-m       1.00      1.00      1.00        28
#       t-SC-s       0.96      1.00      0.98        25
#
#     accuracy                           0.98       212
#    macro avg       0.98      0.98      0.98       212
# weighted avg       0.98      0.98      0.98       212

# %%
# Utilising Hill Climbing technique to obtain a better predictive potential subset of 
# proteins
from sklearn.utils import shuffle
new_Ind = []
cur_MaxScore = 0.0
col_num = 77
col_Ind_Random = shuffle(range(0,col_num), random_state=1)

# %%
for cur_f in range(0, col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = mouse_data_wo_cat.iloc[:, new_Ind]
    X_train, X_test, y_train, y_test = train_test_split(newData, mouse_data["class"], test_size=0.2, random_state=0)
    clf = KNeighborsClassifier(3, weights='distance',p=1)
    fit = clf.fit(X_train, y_train)
    cur_Score = clf.score(X_test, y_test)
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print("Score with " + str(len(new_Ind)) + " selected features: " + str(cur_Score))
# Out:
# Score with 1 selected features: 0.16981132075471697
# Score with 2 selected features: 0.18396226415094338
# Score with 3 selected features: 0.25
# Score with 4 selected features: 0.35377358490566035
# Score with 5 selected features: 0.45754716981132076
# Score with 6 selected features: 0.5
# Score with 7 selected features: 0.5566037735849056
# Score with 8 selected features: 0.5754716981132075
# Score with 9 selected features: 0.6556603773584906
# Score with 10 selected features: 0.7877358490566038
# Score with 11 selected features: 0.8160377358490566
# Score with 12 selected features: 0.8490566037735849
# Score with 13 selected features: 0.8584905660377359
# Score with 14 selected features: 0.9339622641509434
# Score with 15 selected features: 0.9433962264150944
# Score with 16 selected features: 0.9481132075471698
# Score with 17 selected features: 0.9764150943396226
# Score with 18 selected features: 0.9858490566037735
# Score with 19 selected features: 0.9858490566037735
# ...

# %%
# Seeing the new subset of proteins
print(newData.head(0))
# Out:
# Empty DataFrame
# Columns: [Bcatenin_N, NUMB_N, JNK_N, EGR1_N, GluR3_N, GluR4_N, P3525_N, RRP1_N, DSCR1_N, pERK_N, ARC_N, P38_N, BDNF_N, pPKCG_N, pNR2A_N, pGSK3B_N, AKT_N, CaNA_N, pS6_N, PSD95_N, H3MeK4_N, pCASP9_N, NR2B_N, nNOS_N, MTOR_N, SHH_N, RAPTOR_N, CAMKII_N, BAD_N, P70S6_N, Tau_N, pNUMB_N, CDK5_N, pCREB_N, DYRK1A_N, BCL2_N, S6_N, pCAMKII_N, H3AcK18_N, BAX_N, pMEK_N, CREB_N, SOD1_N, APP_N, TIAM1_N, ERBB4_N, ELK_N, NR2A_N, pGSK3B_Tyr216_N, pNR1_N, RSK_N, pP70S6_N, IL1B_N, pJNK_N, Ubiquitin_N, pRSK_N, BRAF_N, AcetylH3K9_N, GSK3B_N, SNCA_N, SYP_N, PKCA_N, AMPKA_N]
# Index: []

# %%
# Building Decision tree classifier as comparison model
# Split the dataset into training and testing datasets
X = mouse_data_wo_cat
y = mouse_data["class"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Checking shapes of training and testing split data
X_train
# Out:
#       DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 515   0.260145  0.465398  0.309689  2.619377  4.128657  0.231519  0.184649
# 948   0.286238  0.519021  0.300679  1.817545  2.763013  0.207565  0.152818
# 664   0.612545  0.848253  0.342264  2.359798  3.996296  0.215212  0.179775
# 640   0.620657  0.850280  0.248359  1.944436  2.798399  0.169095  0.144596
# 453   0.330938  0.561575  0.369450  2.966949  5.445610  0.258227  0.203334
# ...        ...       ...       ...       ...       ...       ...       ...
# 1054  0.268433  0.447237  0.300984  2.157154  3.037699  0.235428  0.178350
# 781   0.382976  0.588608  0.307672  2.771248  5.116507  0.245673  0.177344
# 853   0.391991  0.555107  0.286921  1.939383  2.814475  0.324761  0.212344
# 572   0.956488  1.108441  0.384049  2.662564  4.606357  0.203799  0.171625
# 698   0.643166  0.907501  0.315903  2.317526  3.415074  0.239272  0.184818
#
# ...

# %%
X_train.shape
# Out:
# (847, 77)

# %%
X_test
# Out:
#      DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 427  0.409277  0.545703  0.309686  2.232469  3.765894  0.275580  0.185266
# 205  0.267745  0.409186  0.280010  1.867171  2.740084  0.283664  0.220772
# 696  0.715018  0.925954  0.338903  2.373457  3.556863  0.250807  0.194798
# 320  0.377388  0.630611  0.390998  2.666428  5.101839  0.244389  0.176695
# 270  0.286789  0.497917  0.337858  2.589437  4.283833  0.271469  0.191641
# ..        ...       ...       ...       ...       ...       ...       ...
# 832  0.396521  0.625472  0.268012  2.026588  3.763827  0.218776  0.160512
# 870  0.523508  0.860404  0.355558  2.433010  4.030709  0.185886  0.156083
# 286  0.309432  0.539782  0.347400  2.544861  4.586578  0.237969  0.184401
# 504  0.246061  0.396566  0.269697  2.138182  2.826263  0.186869  0.155758
# 252  0.290638  0.333142  0.268237  1.838599  2.613441  0.193280  0.180069
#
#      pCAMKII_N   pCREB_N    pELK_N    pERK_N    pJNK_N    PKCA_N    pMEK_N  \
# ...

# %%
X_test.shape
# Out:
# (212, 77)

# %%
y_train
# Out:
# 515     c-SC-s
# 948     t-SC-s
# 664     t-CS-m
# 640     t-CS-m
# 453     c-SC-s
#          ...
# 1054    t-SC-s
# 781     t-SC-m
# 853     t-CS-s
# 572     t-CS-m
# 698     t-CS-m
# Name: class, Length: 847, dtype: object

# %%
y_train.shape
# Out:
# (847,)

# %%
y_test
# Out:
# 427    c-CS-s
# 205    c-SC-m
# 696    t-CS-m
# 320    c-CS-s
# 270    c-SC-m
#         ...
# 832    t-SC-m
# 870    t-CS-s
# 286    c-SC-m
# 504    c-SC-s
# 252    c-SC-m
# Name: class, Length: 212, dtype: object

# %%
y_test.shape
# Out:
# (212,)

# %%
# Selecting a decision tree classifier and fitting data
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
fit = clf.fit(X_train, y_train)
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array(['c-CS-s', 'c-SC-m', 't-CS-m', 'c-CS-s', 'c-SC-m', 't-SC-m',
#        't-SC-s', 'c-SC-s', 't-CS-m', 't-SC-s', 't-SC-m', 'c-CS-m',
#        'c-CS-m', 'c-CS-s', 't-SC-m', 't-CS-s', 't-CS-s', 't-SC-m',
#        't-CS-m', 't-CS-m', 'c-CS-m', 't-SC-s', 'c-SC-m', 'c-SC-s',
#        't-CS-m', 't-CS-s', 'c-SC-s', 'c-CS-s', 'c-CS-s', 'c-CS-m',
#        'c-SC-s', 'c-CS-m', 'c-SC-s', 't-CS-s', 'c-SC-m', 'c-CS-s',
#        't-CS-m', 'c-CS-s', 'c-SC-s', 't-CS-m', 'c-SC-m', 'c-CS-m',
#        't-SC-s', 't-SC-m', 't-SC-m', 'c-SC-s', 't-SC-s', 't-SC-m',
#        't-SC-m', 't-CS-m', 't-CS-m', 'c-CS-m', 'c-CS-s', 'c-SC-s',
#        't-SC-s', 'c-CS-s', 't-SC-m', 't-SC-s', 'c-SC-s', 'c-CS-m',
#        't-CS-m', 't-CS-m', 't-CS-m', 't-CS-m', 't-CS-m', 'c-SC-m',
#        't-CS-m', 't-SC-s', 'c-CS-s', 'c-SC-m', 'c-CS-s', 'c-SC-s',
#        't-CS-m', 'c-SC-s', 't-CS-m', 'c-CS-m', 'c-SC-s', 'c-SC-s',
#        'c-SC-m', 'c-SC-s', 'c-SC-m', 'c-SC-s', 'c-CS-m', 'c-SC-m',
# ...

# %%
y_pre.shape
# Out:
# (212,)

# %%
# Evaluating performance
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pre)
print(cm)
# Out:
# [[17  1  0  0  5  3  0  0]
#  [ 3 15  0  0  0  3  0  0]
#  [ 0  1 19  3  0  0  0  0]
#  [ 0  0  1 31  0  0  1  0]
#  [ 2  3  1  0 24  2  0  0]
#  [ 2  1  1  0  6 14  0  0]
#  [ 0  0  1  3  0  0 23  1]
#  [ 0  0  0  0  0  0  0 25]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pre))
# Out:
#               precision    recall  f1-score   support
#
#       c-CS-m       0.71      0.65      0.68        26
#       c-CS-s       0.71      0.71      0.71        21
#       c-SC-m       0.83      0.83      0.83        23
#       c-SC-s       0.84      0.94      0.89        33
#       t-CS-m       0.69      0.75      0.72        32
#       t-CS-s       0.64      0.58      0.61        24
#       t-SC-m       0.96      0.82      0.88        28
#       t-SC-s       0.96      1.00      0.98        25
#
#     accuracy                           0.79       212
#    macro avg       0.79      0.79      0.79       212
# weighted avg       0.79      0.79      0.79       212

# %%
# Experimenting with Decision Tree parameters
# 40 percent of available features 
clf = DecisionTreeClassifier(criterion='gini', max_features=31)
fit = clf.fit(X_train, y_train)
y_pre = fit.predict(X_test)
cm = confusion_matrix(y_test, y_pre)
print(classification_report(y_test, y_pre))
# Out:
#               precision    recall  f1-score   support
#
#       c-CS-m       0.84      0.81      0.82        26
#       c-CS-s       0.58      0.52      0.55        21
#       c-SC-m       0.74      0.87      0.80        23
#       c-SC-s       0.85      0.85      0.85        33
#       t-CS-m       0.76      0.88      0.81        32
#       t-CS-s       0.68      0.62      0.65        24
#       t-SC-m       0.92      0.82      0.87        28
#       t-SC-s       0.96      0.92      0.94        25
#
#     accuracy                           0.80       212
#    macro avg       0.79      0.79      0.79       212
# weighted avg       0.80      0.80      0.80       212

# %%
# Utilising Hill Climbing technique to obtain a better predictive potential subset of 
# proteins
from sklearn.utils import shuffle
new_Ind = []
cur_MaxScore = 0.0
col_num = 77
col_Ind_Random = shuffle(range(0,col_num), random_state=1)

# %%
for cur_f in range(0, col_num):
    new_Ind.append(col_Ind_Random[cur_f])
    newData = mouse_data_wo_cat.iloc[:, new_Ind]
    X_train, X_test, y_train, y_test = train_test_split(newData, mouse_data["class"], test_size=0.2, random_state=0)
    clf = DecisionTreeClassifier(criterion='gini')
    fit = clf.fit(X_train, y_train)
    cur_Score = clf.score(X_test, y_test)
    if cur_Score < cur_MaxScore:
        new_Ind.remove(col_Ind_Random[cur_f])
    else:
        cur_MaxScore = cur_Score
        print("Score with " + str(len(new_Ind)) + " selected features: " + str(cur_Score))
# Out:
# Score with 1 selected features: 0.16037735849056603
# Score with 2 selected features: 0.22641509433962265
# Score with 3 selected features: 0.25471698113207547
# Score with 4 selected features: 0.39622641509433965
# Score with 5 selected features: 0.4339622641509434
# Score with 6 selected features: 0.4858490566037736
# Score with 7 selected features: 0.5188679245283019
# Score with 8 selected features: 0.5377358490566038
# Score with 9 selected features: 0.7028301886792453
# Score with 10 selected features: 0.7075471698113207
# Score with 11 selected features: 0.7075471698113207
# Score with 12 selected features: 0.7075471698113207
# Score with 13 selected features: 0.7075471698113207
# Score with 14 selected features: 0.8018867924528302
# Score with 15 selected features: 0.8160377358490566
# Score with 16 selected features: 0.8207547169811321
# Score with 17 selected features: 0.839622641509434
# Score with 18 selected features: 0.8443396226415094
# ...

# %%
# Seeing the new subset of proteins
print(newData.head(0))
# Out:
# Empty DataFrame
# Columns: [Bcatenin_N, NUMB_N, JNK_N, EGR1_N, GluR3_N, GluR4_N, P3525_N, RRP1_N, pERK_N, ARC_N, P38_N, BDNF_N, MEK_N, pPKCG_N, PSD95_N, H3MeK4_N, pCASP9_N, BAD_N, NR1_N, CDK5_N, BCL2_N, pCAMKII_N, H3AcK18_N, pRSK_N, BRAF_N, AcetylH3K9_N, AMPKA_N]
# Index: []
